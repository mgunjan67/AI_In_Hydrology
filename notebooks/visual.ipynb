# %%
import pandas as pd
df = pd.read_csv('df.csv')
df.head()
# Out:
#    Unnamed: 0        Date  runoff_value Station_Type  Value  Station Type  \
# 0           0  1980-01-02         118.0      601_ppt    0.0      601  ppt
# 1           1  1980-01-03         114.0      601_ppt    0.0      601  ppt
# 2           2  1980-01-04         111.0      601_ppt    0.0      601  ppt
# 3           3  1980-01-05         111.0      601_ppt    0.0      601  ppt
# 4           4  1980-01-06         108.0      601_ppt    0.0      601  ppt
#
#     Latitude  Longitude  Elevation
# 0  28.783333  83.716667       2744
# 1  28.783333  83.716667       2744
# 2  28.783333  83.716667       2744
# 3  28.783333  83.716667       2744
# 4  28.783333  83.716667       2744
